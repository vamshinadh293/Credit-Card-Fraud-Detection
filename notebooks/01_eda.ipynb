# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv("../Data/creditcard.csv")

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.175161e-15  3.384974e-16 -1.379537e-15  2.094852e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   1.021879e-15  1.494498e-15 -5.620335e-16  1.149614e-16 -2.414189e-15
# ...

# %%
df["Class"].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
df["Class"].value_counts(normalize=True) * 100
# Out:
# Class
# 0    99.827251
# 1     0.172749
# Name: proportion, dtype: float64

# %%
# %pip install seaborn matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x="Class", data=df)

plt.title("Transaction Class Distribution")
plt.xlabel("Class (0 = Legitimate, 1 = Fraud)")
plt.ylabel("Number of Transactions")
plt.show()

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(1081)

# %%
df.shape
df["Class"].value_counts()
df["Class"].value_counts(normalize=True) * 100
df.isnull().sum()
df.duplicated().sum()
# Out:
# np.int64(1081)

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.duplicated().sum()
# Out:
# np.int64(1081)

# %%
df["Amount"].describe()
# Out:
# count    284807.000000
# mean         88.349619
# std         250.120109
# min           0.000000
# 25%           5.600000
# 50%          22.000000
# 75%          77.165000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
df["Time"].describe()
# Out:
# count    284807.000000
# mean      94813.859575
# std       47488.145955
# min           0.000000
# 25%       54201.500000
# 50%       84692.000000
# 75%      139320.500000
# max      172792.000000
# Name: Time, dtype: float64

# %%
df.groupby("Class")["Amount"].describe()
# Out:
#           count        mean         std  min   25%    50%     75%       max
# Class
# 0      284315.0   88.291022  250.105092  0.0  5.65  22.00   77.05  25691.16
# 1         492.0  122.211321  256.683288  0.0  1.00   9.25  105.89   2125.87

# %%
df.groupby("Class")["Time"].describe()
# Out:
#           count          mean           std    min      25%      50%  \
# Class
# 0      284315.0  94838.202258  47484.015786    0.0  54230.0  84711.0
# 1         492.0  80746.806911  47835.365138  406.0  41241.5  75568.5
#
#             75%       max
# Class
# 0      139333.0  172792.0
# 1      128483.0  170348.0

# %%
plt.figure(figsize=(8, 5))

sns.boxplot(
    x="Class",
    y="Amount",
    data=df
)

plt.title("Transaction Amount by Class")
plt.xlabel("Class (0 = Legitimate, 1 = Fraud)")
plt.ylabel("Transaction Amount")
plt.ylim(0, 500)

plt.show()

# %%
plt.figure(figsize=(10, 5))

sns.histplot(
    data=df,
    x="Amount",
    hue="Class",
    bins=50,
    kde=True,
    stat="density",
    common_norm=False
)

plt.xlim(0, 500)
plt.title("Transaction Amount Distribution")
plt.show()

# %%
feature_means = df.groupby("Class").mean(numeric_only=True).T

feature_means["difference"] = (
    feature_means[1] - feature_means[0]
)

feature_means.sort_values(
    "difference",
    key=abs,
    ascending=False
).head(10)
# Out:
# Class              0             1    difference
# Time    94838.202258  80746.806911 -14091.395347
# Amount     88.291022    122.211321     33.920299
# V3          0.012171     -7.033281     -7.045452
# V14         0.012064     -6.971723     -6.983787
# V17         0.011535     -6.665836     -6.677371
# V12         0.010832     -6.259393     -6.270225
# V10         0.009824     -5.676883     -5.686707
# V7          0.009637     -5.568731     -5.578368
# V1          0.008258     -4.771948     -4.780206
# V4         -0.007860      4.542029      4.549889

# %%
feature_medians = df.groupby("Class").median(numeric_only=True).T

feature_medians["difference"] = (
    feature_medians[1] - feature_medians[0]
)

feature_medians.sort_values(
    "difference",
    key=abs,
    ascending=False
).head(10)
# Out:
# Class              0             1   difference
# Time    84711.000000  75568.500000 -9142.500000
# Amount     22.000000      9.250000   -12.750000
# V14         0.051947     -6.729720    -6.781667
# V12         0.141679     -5.502530    -5.644208
# V3          0.182158     -5.075257    -5.257415
# V17        -0.064833     -5.302949    -5.238115
# V10        -0.091872     -4.578825    -4.486953
# V4         -0.022405      4.177147     4.199552
# V11        -0.034923      3.586218     3.621142
# V16         0.067377     -3.549795    -3.617172

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.duplicated().sum()
# Out:
# np.int64(1081)

# %%
df[df.duplicated(keep=False)].sort_values(
    by=list(df.columns)
).head(20)
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 34      26.0 -0.535388  0.865268  1.351076  0.147575  0.433680  0.086983
# 35      26.0 -0.535388  0.865268  1.351076  0.147575  0.433680  0.086983
# 32      26.0 -0.529912  0.873892  1.347247  0.145457  0.414209  0.100223
# 33      26.0 -0.529912  0.873892  1.347247  0.145457  0.414209  0.100223
# 112     74.0  1.038370  0.127486  0.184456  1.109950  0.441699  0.945283
# 113     74.0  1.038370  0.127486  0.184456  1.109950  0.441699  0.945283
# 114     74.0  1.038370  0.127486  0.184456  1.109950  0.441699  0.945283
# 115     74.0  1.038370  0.127486  0.184456  1.109950  0.441699  0.945283
# 220    145.0 -2.420413  1.947885  0.553646  0.983069 -0.281518  2.408958
# 221    145.0 -2.420413  1.947885  0.553646  0.983069 -0.281518  2.408958
# 222    145.0 -2.419486  1.949346  0.552998  0.982710 -0.284815  2.411200
# 223    145.0 -2.419486  1.949346  0.552998  0.982710 -0.284815  2.411200
# ...

# %%
df[df.duplicated(keep=False)]["Class"].value_counts()
# Out:
# Class
# 0    1822
# 1      32
# Name: count, dtype: int64

# %%
df["Amount_log"] = np.log1p(df["Amount"])

# %%
df[["Amount", "Amount_log"]].describe()
# Out:
#               Amount     Amount_log
# count  284807.000000  284807.000000
# mean       88.349619       3.152188
# std       250.120109       1.656648
# min         0.000000       0.000000
# 25%         5.600000       1.887070
# 50%        22.000000       3.135494
# 75%        77.165000       4.358822
# max     25691.160000      10.153941

# %%
df["Time_hour"] = (df["Time"] // 3600) % 24

# %%
df["Time_day"] = df["Time"] // (3600 * 24)

# %%
df[[
    "Time",
    "Time_hour",
    "Time_day",
    "Amount",
    "Amount_log"
]].head(20)
# Out:
#     Time  Time_hour  Time_day  Amount  Amount_log
# 0    0.0        0.0       0.0  149.62    5.014760
# 1    0.0        0.0       0.0    2.69    1.305626
# 2    1.0        0.0       0.0  378.66    5.939276
# 3    1.0        0.0       0.0  123.50    4.824306
# 4    2.0        0.0       0.0   69.99    4.262539
# 5    2.0        0.0       0.0    3.67    1.541159
# 6    4.0        0.0       0.0    4.99    1.790091
# 7    7.0        0.0       0.0   40.80    3.732896
# 8    7.0        0.0       0.0   93.20    4.545420
# 9    9.0        0.0       0.0    3.68    1.543298
# 10  10.0        0.0       0.0    7.80    2.174752
# 11  10.0        0.0       0.0    9.99    2.396986
# 12  10.0        0.0       0.0  121.50    4.808111
# 13  11.0        0.0       0.0   27.50    3.349904
# 14  12.0        0.0       0.0   58.80    4.091006
# 15  12.0        0.0       0.0   15.99    2.832625
# 16  12.0        0.0       0.0   12.99    2.638343
# 17  13.0        0.0       0.0    0.89    0.636577
# ...

# %%
df.groupby("Class")[[
    "Time_hour",
    "Time_day",
    "Amount_log"
]].mean()
# Out:
#        Time_hour  Time_day  Amount_log
# Class
# 0      14.050623  0.491743    3.152762
# 1      11.646341  0.428862    2.820596

# %%
df[df.duplicated(keep=False)]["Class"].value_counts()
# Out:
# Class
# 0    1822
# 1      32
# Name: count, dtype: int64

# %%
df["Amount_log"] = np.log1p(df["Amount"])
df["Time_hour"] = (df["Time"] // 3600) % 24
df["Time_day"] = df["Time"] // (3600 * 24)

# %%
df[[
    "Time", "Time_hour", "Time_day",
    "Amount", "Amount_log"
]].head()
# Out:
#    Time  Time_hour  Time_day  Amount  Amount_log
# 0   0.0        0.0       0.0  149.62    5.014760
# 1   0.0        0.0       0.0    2.69    1.305626
# 2   1.0        0.0       0.0  378.66    5.939276
# 3   1.0        0.0       0.0  123.50    4.824306
# 4   2.0        0.0       0.0   69.99    4.262539

# %%
X = df.drop(columns=["Class"])
y = df["Class"]

# %%
print(X.shape)
print(y.shape)
# Out:
# (284807, 33)
# (284807,)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    stratify=y,
    random_state=42
)

# %%
print("Training distribution:")
print(y_train.value_counts(normalize=True) * 100)

print("\nTest distribution:")
print(y_test.value_counts(normalize=True) * 100)
# Out:
# Training distribution:
# Class
# 0    99.827075
# 1     0.172925
# Name: proportion, dtype: float64
#
# Test distribution:
# Class
# 0    99.827955
# 1     0.172045
# Name: proportion, dtype: float64

# %%
from sklearn.dummy import DummyClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

dummy = DummyClassifier(
    strategy="most_frequent"
)

dummy.fit(X_train, y_train)

y_pred_dummy = dummy.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred_dummy))
print("Precision:", precision_score(y_test, y_pred_dummy, zero_division=0))
print("Recall:", recall_score(y_test, y_pred_dummy, zero_division=0))
print("F1:", f1_score(y_test, y_pred_dummy, zero_division=0))
# Out:
# Accuracy: 0.9982795547909132
# Precision: 0.0
# Recall: 0.0
# F1: 0.0

# %%
print("Duplicate rows:", df.duplicated().sum())
print("\nClass distribution among duplicate rows:")
print(df[df.duplicated(keep=False)]["Class"].value_counts())
# Out:
# Duplicate rows: 1081
#
# Class distribution among duplicate rows:
# Class
# 0    1822
# 1      32
# Name: count, dtype: int64

# %%
print("Fraud transactions among exact duplicate groups:")

duplicates = df[df.duplicated(keep=False)]

print(
    duplicates.groupby("Class").size()
)
# Out:
# Fraud transactions among exact duplicate groups:
# Class
# 0    1822
# 1      32
# dtype: int64

# %%
df = df.drop_duplicates().reset_index(drop=True)

# %%
print("Shape after removing duplicates:", df.shape)
print("Remaining duplicates:", df.duplicated().sum())
print("\nClass distribution:")
print(df["Class"].value_counts())
print("\nClass percentage:")
print(df["Class"].value_counts(normalize=True) * 100)
# Out:
# Shape after removing duplicates: (283726, 34)
# Remaining duplicates: 0
#
# Class distribution:
# Class
# 0    283253
# 1       473
# Name: count, dtype: int64
#
# Class percentage:
# Class
# 0    99.83329
# 1     0.16671
# Name: proportion, dtype: float64

# %%
df["Amount_log"] = np.log1p(df["Amount"])

df["Time_hour"] = (df["Time"] // 3600) % 24

df["Time_day"] = df["Time"] // (3600 * 24)

# %%
print("Shape:", df.shape)
print("Duplicates:", df.duplicated().sum())
print(df["Class"].value_counts())
# Out:
# Shape: (283726, 34)
# Duplicates: 0
# Class
# 0    283253
# 1       473
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X = df.drop(columns=["Class"])
y = df["Class"]

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    stratify=y,
    random_state=42
)

# %%
print("Training set:")
print(y_train.value_counts())
print(y_train.value_counts(normalize=True) * 100)

print("\nTest set:")
print(y_test.value_counts())
print(y_test.value_counts(normalize=True) * 100)
# Out:
# Training set:
# Class
# 0    226602
# 1       378
# Name: count, dtype: int64
# Class
# 0    99.833466
# 1     0.166534
# Name: proportion, dtype: float64
#
# Test set:
# Class
# 0    56651
# 1       95
# Name: count, dtype: int64
# Class
# 0    99.832587
# 1     0.167413
# Name: proportion, dtype: float64

# %%
from sklearn.dummy import DummyClassifier
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score
)

dummy = DummyClassifier(strategy="most_frequent")

dummy.fit(X_train, y_train)

y_pred_dummy = dummy.predict(X_test)

print("Accuracy :", accuracy_score(y_test, y_pred_dummy))
print("Precision:", precision_score(y_test, y_pred_dummy, zero_division=0))
print("Recall   :", recall_score(y_test, y_pred_dummy, zero_division=0))
print("F1       :", f1_score(y_test, y_pred_dummy, zero_division=0))
# Out:
# Accuracy : 0.9983258731892997
# Precision: 0.0
# Recall   : 0.0
# F1       : 0.0

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline

logistic_model = Pipeline([
    ("scaler", StandardScaler()),
    ("classifier", LogisticRegression(
        class_weight="balanced",
        max_iter=1000,
        random_state=42
    ))
])

logistic_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('classifier',
#                  LogisticRegression(class_weight='balanced', max_iter=1000,
#                                     random_state=42))])

# %%
y_pred = logistic_model.predict(X_test)

y_prob = logistic_model.predict_proba(X_test)[:, 1]

# %%
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    average_precision_score,
    roc_auc_score,
    classification_report
)

print("Accuracy :", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred))
print("Recall   :", recall_score(y_test, y_pred))
print("F1       :", f1_score(y_test, y_pred))
print("PR-AUC   :", average_precision_score(y_test, y_prob))
print("ROC-AUC  :", roc_auc_score(y_test, y_prob))

print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy : 0.9748176082895711
# Precision: 0.05533333333333333
# Recall   : 0.8736842105263158
# F1       : 0.10407523510971786
# PR-AUC   : 0.670920116698408
# ROC-AUC  : 0.9682803016437671
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99     56651
#            1       0.06      0.87      0.10        95
#
#     accuracy                           0.97     56746
#    macro avg       0.53      0.92      0.55     56746
# weighted avg       1.00      0.97      0.99     56746

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(6, 5))

sns.heatmap(
    cm,
    annot=True,
    fmt="d"
)

plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Logistic Regression - Fraud Detection")
plt.show()

# %%
thresholds = [0.20, 0.30, 0.40, 0.50, 0.60]

results = []

for threshold in thresholds:

    y_pred_threshold = (y_prob >= threshold).astype(int)

    results.append({
        "Threshold": threshold,
        "Accuracy": accuracy_score(y_test, y_pred_threshold),
        "Precision": precision_score(
            y_test,
            y_pred_threshold,
            zero_division=0
        ),
        "Recall": recall_score(
            y_test,
            y_pred_threshold,
            zero_division=0
        ),
        "F1": f1_score(
            y_test,
            y_pred_threshold,
            zero_division=0
        )
    })

threshold_results = pd.DataFrame(results)

threshold_results
# Out:
#    Threshold  Accuracy  Precision    Recall        F1
# 0        0.2  0.912663   0.016895  0.894737  0.033164
# 1        0.3  0.946763   0.026843  0.873684  0.052087
# 2        0.4  0.964050   0.039318  0.873684  0.075249
# 3        0.5  0.974818   0.055333  0.873684  0.104075
# 4        0.6  0.982237   0.076923  0.873684  0.141397

# %%
for threshold in thresholds:

    y_pred_threshold = (y_prob >= threshold).astype(int)

    tn, fp, fn, tp = confusion_matrix(
        y_test,
        y_pred_threshold
    ).ravel()

    print(f"\nThreshold: {threshold}")
    print(f"TN: {tn}")
    print(f"FP: {fp}")
    print(f"FN: {fn}")
    print(f"TP: {tp}")
# Out:
# Threshold: 0.2
# TN: 51705
# FP: 4946
# FN: 10
# TP: 85
#
# Threshold: 0.3
# TN: 53642
# FP: 3009
# FN: 12
# TP: 83
#
# Threshold: 0.4
# TN: 54623
# FP: 2028
# FN: 12
# TP: 83
#
# Threshold: 0.5
# TN: 55234
# FP: 1417
# FN: 12
# TP: 83
#
# Threshold: 0.6
# TN: 55655
# FP: 996
# FN: 12
# TP: 83

# %%
fp_cost = 100
fn_cost = 1000

cost_results = []

for threshold in thresholds:

    y_pred_threshold = (y_prob >= threshold).astype(int)

    tn, fp, fn, tp = confusion_matrix(
        y_test,
        y_pred_threshold
    ).ravel()

    total_cost = (
        fp * fp_cost +
        fn * fn_cost
    )

    cost_results.append({
        "Threshold": threshold,
        "FP": fp,
        "FN": fn,
        "TP": tp,
        "Total_Cost": total_cost
    })

cost_df = pd.DataFrame(cost_results)

cost_df
# Out:
#    Threshold    FP  FN  TP  Total_Cost
# 0        0.2  4946  10  85      504600
# 1        0.3  3009  12  83      312900
# 2        0.4  2028  12  83      214800
# 3        0.5  1417  12  83      153700
# 4        0.6   996  12  83      111600

# %%
plt.figure(figsize=(8, 5))

plt.plot(
    cost_df["Threshold"],
    cost_df["Total_Cost"],
    marker="o"
)

plt.xlabel("Decision Threshold")
plt.ylabel("Operational Cost")
plt.title("Operational Cost vs Decision Threshold")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 5))

plt.plot(
    threshold_results["Threshold"],
    threshold_results["Precision"],
    marker="o",
    label="Precision"
)

plt.plot(
    threshold_results["Threshold"],
    threshold_results["Recall"],
    marker="o",
    label="Recall"
)

plt.plot(
    threshold_results["Threshold"],
    threshold_results["F1"],
    marker="o",
    label="F1"
)

plt.xlabel("Decision Threshold")
plt.ylabel("Score")
plt.title("Precision-Recall-F1 vs Threshold")
plt.legend()
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import precision_recall_curve, average_precision_score

precision, recall, pr_thresholds = precision_recall_curve(
    y_test,
    y_prob
)

pr_auc = average_precision_score(y_test, y_prob)

print("PR-AUC:", pr_auc)
# Out:
# PR-AUC: 0.670920116698408

# %%
plt.figure(figsize=(8, 6))

plt.plot(
    recall,
    precision
)

plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title(f"Precision-Recall Curve (AP = {pr_auc:.3f})")
plt.grid(True)

plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier(
    n_estimators=200,
    class_weight="balanced",
    random_state=42,
    n_jobs=-1
)

rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', n_estimators=200, n_jobs=-1,
#                        random_state=42)

# %%
y_pred_rf = rf_model.predict(X_test)

y_prob_rf = rf_model.predict_proba(X_test)[:, 1]

# %%
print("Accuracy :", accuracy_score(y_test, y_pred_rf))
print("Precision:", precision_score(y_test, y_pred_rf, zero_division=0))
print("Recall   :", recall_score(y_test, y_pred_rf, zero_division=0))
print("F1       :", f1_score(y_test, y_pred_rf, zero_division=0))
print("PR-AUC   :", average_precision_score(y_test, y_prob_rf))
print("ROC-AUC  :", roc_auc_score(y_test, y_prob_rf))
# Out:
# Accuracy : 0.9994889507630493
# Precision: 0.9583333333333334
# Recall   : 0.7263157894736842
# F1       : 0.8263473053892215
# PR-AUC   : 0.8167185273415173
# ROC-AUC  : 0.9425125584255958

# %%
cm_rf = confusion_matrix(y_test, y_pred_rf)

plt.figure(figsize=(6, 5))

sns.heatmap(
    cm_rf,
    annot=True,
    fmt="d"
)

plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Random Forest - Fraud Detection")

plt.show()

# %%
precision_rf, recall_rf, thresholds_rf = precision_recall_curve(
    y_test,
    y_prob_rf
)

pr_auc_rf = average_precision_score(
    y_test,
    y_prob_rf
)

plt.figure(figsize=(8, 6))

plt.plot(
    recall_rf,
    precision_rf
)

plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title(f"Random Forest Precision-Recall Curve (AP = {pr_auc_rf:.3f})")
plt.grid(True)

plt.show()

# %%
plt.figure(figsize=(9, 6))

precision_lr, recall_lr, _ = precision_recall_curve(
    y_test,
    y_prob
)

precision_rf, recall_rf, _ = precision_recall_curve(
    y_test,
    y_prob_rf
)

plt.plot(
    recall_lr,
    precision_lr,
    label=f"Logistic Regression (AP={average_precision_score(y_test, y_prob):.3f})"
)

plt.plot(
    recall_rf,
    precision_rf,
    label=f"Random Forest (AP={average_precision_score(y_test, y_prob_rf):.3f})"
)

plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision-Recall Curve Comparison")

plt.legend()
plt.grid(True)
plt.show()

# %%
thresholds = [0.20, 0.30, 0.40, 0.50, 0.60]
rf_threshold_results = []

for threshold in thresholds:

    y_pred_threshold = (
        y_prob_rf >= threshold
    ).astype(int)

    tn, fp, fn, tp = confusion_matrix(
        y_test,
        y_pred_threshold
    ).ravel()

    rf_threshold_results.append({
        "Threshold": threshold,
        "TN": tn,
        "FP": fp,
        "FN": fn,
        "TP": tp,
        "Precision": precision_score(
            y_test,
            y_pred_threshold,
            zero_division=0
        ),
        "Recall": recall_score(
            y_test,
            y_pred_threshold,
            zero_division=0
        ),
        "F1": f1_score(
            y_test,
            y_pred_threshold,
            zero_division=0
        )
    })

rf_threshold_df = pd.DataFrame(rf_threshold_results)

rf_threshold_df
# Out:
#    Threshold     TN  FP  FN  TP  Precision    Recall        F1
# 0        0.2  56639  12  18  77   0.865169  0.810526  0.836957
# 1        0.3  56645   6  21  74   0.925000  0.778947  0.845714
# 2        0.4  56646   5  24  71   0.934211  0.747368  0.830409
# 3        0.5  56648   3  26  69   0.958333  0.726316  0.826347
# 4        0.6  56648   3  27  68   0.957746  0.715789  0.819277

# %%
fp_cost = 100
fn_cost = 1000

rf_threshold_df["Total_Cost"] = (
    rf_threshold_df["FP"] * fp_cost
    + rf_threshold_df["FN"] * fn_cost
)

rf_threshold_df
# Out:
#    Threshold     TN  FP  FN  TP  Precision    Recall        F1  Total_Cost
# 0        0.2  56639  12  18  77   0.865169  0.810526  0.836957       19200
# 1        0.3  56645   6  21  74   0.925000  0.778947  0.845714       21600
# 2        0.4  56646   5  24  71   0.934211  0.747368  0.830409       24500
# 3        0.5  56648   3  26  69   0.958333  0.726316  0.826347       26300
# 4        0.6  56648   3  27  68   0.957746  0.715789  0.819277       27300

# %%
from xgboost import XGBClassifier

# %%
negative = (y_train == 0).sum()
positive = (y_train == 1).sum()

scale_pos_weight = negative / positive

print("Negative:", negative)
print("Positive:", positive)
print("scale_pos_weight:", scale_pos_weight)
# Out:
# Negative: 226602
# Positive: 378
# scale_pos_weight: 599.4761904761905

# %%
xgb_model = XGBClassifier(
    n_estimators=300,
    max_depth=4,
    learning_rate=0.05,
    subsample=0.8,
    colsample_bytree=0.8,
    scale_pos_weight=scale_pos_weight,
    random_state=42,
    eval_metric="logloss",
    n_jobs=-1
)

# %%
xgb_model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=4, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=300, n_jobs=-1,
#               num_parallel_tree=None, ...)

# %%
y_pred_xgb = xgb_model.predict(X_test)

y_prob_xgb = xgb_model.predict_proba(X_test)[:, 1]

# %%
print("Accuracy :", accuracy_score(y_test, y_pred_xgb))
print("Precision:", precision_score(y_test, y_pred_xgb, zero_division=0))
print("Recall   :", recall_score(y_test, y_pred_xgb, zero_division=0))
print("F1       :", f1_score(y_test, y_pred_xgb, zero_division=0))
print("PR-AUC   :", average_precision_score(y_test, y_prob_xgb))
print("ROC-AUC  :", roc_auc_score(y_test, y_prob_xgb))
# Out:
# Accuracy : 0.9989426567511367
# Precision: 0.6470588235294118
# Recall   : 0.8105263157894737
# F1       : 0.719626168224299
# PR-AUC   : 0.8128632616569708
# ROC-AUC  : 0.9789568447251826

# %%
cm_xgb = confusion_matrix(y_test, y_pred_xgb)

plt.figure(figsize=(6, 5))

sns.heatmap(
    cm_xgb,
    annot=True,
    fmt="d"
)

plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("XGBoost - Fraud Detection")

plt.show()

# %%
xgb_threshold_results = []

for threshold in thresholds:

    y_pred_threshold = (
        y_prob_xgb >= threshold
    ).astype(int)

    tn, fp, fn, tp = confusion_matrix(
        y_test,
        y_pred_threshold
    ).ravel()

    xgb_threshold_results.append({
        "Threshold": threshold,
        "TN": tn,
        "FP": fp,
        "FN": fn,
        "TP": tp,
        "Precision": precision_score(
            y_test,
            y_pred_threshold,
            zero_division=0
        ),
        "Recall": recall_score(
            y_test,
            y_pred_threshold,
            zero_division=0
        ),
        "F1": f1_score(
            y_test,
            y_pred_threshold,
            zero_division=0
        )
    })

xgb_threshold_df = pd.DataFrame(
    xgb_threshold_results
)

xgb_threshold_df
# Out:
#    Threshold     TN   FP  FN  TP  Precision    Recall        F1
# 0        0.2  56519  132  16  79   0.374408  0.831579  0.516340
# 1        0.3  56574   77  16  79   0.506410  0.831579  0.629482
# 2        0.4  56595   56  18  77   0.578947  0.810526  0.675439
# 3        0.5  56609   42  18  77   0.647059  0.810526  0.719626
# 4        0.6  56620   31  19  76   0.710280  0.800000  0.752475

# %%
fp_cost = 100
fn_cost = 1000

xgb_threshold_df["Total_Cost"] = (
    xgb_threshold_df["FP"] * fp_cost
    + xgb_threshold_df["FN"] * fn_cost
)

xgb_threshold_df
# Out:
#    Threshold     TN   FP  FN  TP  Precision    Recall        F1  Total_Cost
# 0        0.2  56519  132  16  79   0.374408  0.831579  0.516340       29200
# 1        0.3  56574   77  16  79   0.506410  0.831579  0.629482       23700
# 2        0.4  56595   56  18  77   0.578947  0.810526  0.675439       23600
# 3        0.5  56609   42  18  77   0.647059  0.810526  0.719626       22200
# 4        0.6  56620   31  19  76   0.710280  0.800000  0.752475       22100

# %%
from sklearn.calibration import calibration_curve

prob_true, prob_pred = calibration_curve(
    y_test,
    y_prob_xgb,
    n_bins=10,
    strategy="quantile"
)

plt.figure(figsize=(8, 6))

plt.plot(
    prob_pred,
    prob_true,
    marker="o",
    label="XGBoost"
)

plt.plot(
    [0, 1],
    [0, 1],
    linestyle="--",
    label="Perfect Calibration"
)

plt.xlabel("Mean Predicted Probability")
plt.ylabel("Fraction of Positives")
plt.title("XGBoost Calibration Curve")

plt.legend()
plt.grid(True)

plt.show()

# %%
from sklearn.metrics import brier_score_loss

brier = brier_score_loss(
    y_test,
    y_prob_xgb
)

print("Brier Score:", brier)
# Out:
# Brier Score: 0.0009757732623256743

# %%
from sklearn.calibration import CalibratedClassifierCV

calibrated_xgb = CalibratedClassifierCV(
    xgb_model,
    method="sigmoid",
    cv=5,
    n_jobs=-1
)

# %%
calibrated_xgb.fit(X_train, y_train)
# Out:
# CalibratedClassifierCV(cv=5,
#                        estimator=XGBClassifier(base_score=None, booster=None,
#                                                callbacks=None,
#                                                colsample_bylevel=None,
#                                                colsample_bynode=None,
#                                                colsample_bytree=0.8,
#                                                device=None,
#                                                early_stopping_rounds=None,
#                                                enable_categorical=False,
#                                                eval_metric='logloss',
#                                                feature_types=None,
#                                                feature_weights=None, gamma=None,
#                                                grow_policy=None,
#                                                importance_type=None,
# ...

# %%
y_prob_calibrated = calibrated_xgb.predict_proba(X_test)[:, 1]

brier_calibrated = brier_score_loss(
    y_test,
    y_prob_calibrated
)

print("Calibrated Brier Score:", brier_calibrated)
# Out:
# Calibrated Brier Score: 0.0004811713876534026

# %%
prob_true_cal, prob_pred_cal = calibration_curve(
    y_test,
    y_prob_calibrated,
    n_bins=10,
    strategy="quantile"
)

plt.figure(figsize=(8, 6))

plt.plot(
    prob_pred_cal,
    prob_true_cal,
    marker="o",
    label="Calibrated XGBoost"
)

plt.plot(
    [0, 1],
    [0, 1],
    linestyle="--",
    label="Perfect Calibration"
)

plt.xlabel("Mean Predicted Probability")
plt.ylabel("Fraction of Positives")
plt.title("Calibrated XGBoost Calibration Curve")

plt.legend()
plt.grid(True)

plt.show()

# %%
y_pred_calibrated = (
    y_prob_calibrated >= 0.5
).astype(int)

print("Accuracy :", accuracy_score(y_test, y_pred_calibrated))
print("Precision:", precision_score(
    y_test, y_pred_calibrated, zero_division=0
))
print("Recall   :", recall_score(
    y_test, y_pred_calibrated, zero_division=0
))
print("F1       :", f1_score(
    y_test, y_pred_calibrated, zero_division=0
))
print("PR-AUC   :", average_precision_score(
    y_test, y_prob_calibrated
))
print("ROC-AUC  :", roc_auc_score(
    y_test, y_prob_calibrated
))
# Out:
# Accuracy : 0.9994713283755683
# Precision: 0.891566265060241
# Recall   : 0.7789473684210526
# F1       : 0.8314606741573034
# PR-AUC   : 0.8175417229353614
# ROC-AUC  : 0.9762514528010375

# %%
cm_calibrated = confusion_matrix(
    y_test,
    y_pred_calibrated
)

print(cm_calibrated)
# Out:
# [[56642     9]
#  [   21    74]]

# %%
print("Raw XGBoost probabilities:")
print(pd.Series(y_prob_xgb).describe())

print("\nCalibrated probabilities:")
print(pd.Series(y_prob_calibrated).describe())
# Out:
# Raw XGBoost probabilities:
# count    56746.000000
# mean         0.004836
# std          0.044608
# min          0.000002
# 25%          0.000120
# 50%          0.000333
# 75%          0.001072
# max          0.999917
# dtype: float64
#
# Calibrated probabilities:
# count    56746.000000
# mean         0.001559
# std          0.032175
# min          0.000234
# 25%          0.000234
# 50%          0.000235
# 75%          0.000236
# max          0.855095
# dtype: float64

# %%
X_train
X_test
y_train
y_test
# Out:
# 86249     0
# 250634    0
# 20163     0
# 68688     0
# 191151    0
#          ..
# 56277     0
# 187751    0
# 115100    0
# 186966    0
# 8228      0
# Name: Class, Length: 56746, dtype: int64

# %%
X_fit, X_val, y_fit, y_val = train_test_split(
    X_train,
    y_train,
    test_size=0.20,
    stratify=y_train,
    random_state=42
)

# %%
print("Fit:", X_fit.shape)
print("Validation:", X_val.shape)
print("Test:", X_test.shape)

print("\nFraud counts:")
print("Fit:", y_fit.sum())
print("Validation:", y_val.sum())
print("Test:", y_test.sum())
# Out:
# Fit: (181584, 33)
# Validation: (45396, 33)
# Test: (56746, 33)
#
# Fraud counts:
# Fit: 302
# Validation: 76
# Test: 95

# %%
negative = (y_fit == 0).sum()
positive = (y_fit == 1).sum()

scale_pos_weight = negative / positive

print("scale_pos_weight:", scale_pos_weight)
# Out:
# scale_pos_weight: 600.2715231788079

# %%
xgb_final = XGBClassifier(
    n_estimators=300,
    max_depth=4,
    learning_rate=0.05,
    subsample=0.8,
    colsample_bytree=0.8,
    scale_pos_weight=scale_pos_weight,
    random_state=42,
    eval_metric="logloss",
    n_jobs=-1
)

# %%
calibrated_final = CalibratedClassifierCV(
    xgb_final,
    method="sigmoid",
    cv=5,
    n_jobs=-1
)

calibrated_final.fit(X_fit, y_fit)
# Out:
# CalibratedClassifierCV(cv=5,
#                        estimator=XGBClassifier(base_score=None, booster=None,
#                                                callbacks=None,
#                                                colsample_bylevel=None,
#                                                colsample_bynode=None,
#                                                colsample_bytree=0.8,
#                                                device=None,
#                                                early_stopping_rounds=None,
#                                                enable_categorical=False,
#                                                eval_metric='logloss',
#                                                feature_types=None,
#                                                feature_weights=None, gamma=None,
#                                                grow_policy=None,
#                                                importance_type=None,
# ...

# %%
y_prob_val = calibrated_final.predict_proba(X_val)[:, 1]

thresholds = [0.20, 0.30, 0.40, 0.50, 0.60]

validation_results = []

for threshold in thresholds:

    y_pred_val = (
        y_prob_val >= threshold
    ).astype(int)

    tn, fp, fn, tp = confusion_matrix(
        y_val,
        y_pred_val
    ).ravel()

    total_cost = (
        fp * 100 +
        fn * 1000
    )

    validation_results.append({
        "Threshold": threshold,
        "TN": tn,
        "FP": fp,
        "FN": fn,
        "TP": tp,
        "Precision": precision_score(
            y_val, y_pred_val, zero_division=0
        ),
        "Recall": recall_score(
            y_val, y_pred_val, zero_division=0
        ),
        "F1": f1_score(
            y_val, y_pred_val, zero_division=0
        ),
        "Total_Cost": total_cost
    })

validation_df = pd.DataFrame(validation_results)

validation_df
# Out:
#    Threshold     TN  FP  FN  TP  Precision    Recall        F1  Total_Cost
# 0        0.2  45311   9  11  65   0.878378  0.855263  0.866667       11900
# 1        0.3  45313   7  11  65   0.902778  0.855263  0.878378       11700
# 2        0.4  45314   6  11  65   0.915493  0.855263  0.884354       11600
# 3        0.5  45314   6  11  65   0.915493  0.855263  0.884354       11600
# 4        0.6  45314   6  11  65   0.915493  0.855263  0.884354       11600

# %%
final_threshold = 0.40

y_prob_test_final = calibrated_final.predict_proba(
    X_test
)[:, 1]

y_pred_test_final = (
    y_prob_test_final >= final_threshold
).astype(int)

# %%
print("Final Test Results")
print("-------------------")

print(
    "Accuracy :",
    accuracy_score(y_test, y_pred_test_final)
)

print(
    "Precision:",
    precision_score(
        y_test,
        y_pred_test_final,
        zero_division=0
    )
)

print(
    "Recall   :",
    recall_score(
        y_test,
        y_pred_test_final,
        zero_division=0
    )
)

print(
    "F1       :",
    f1_score(
        y_test,
        y_pred_test_final,
        zero_division=0
    )
)

print(
    "PR-AUC   :",
    average_precision_score(
        y_test,
        y_prob_test_final
    )
)

print(
    "ROC-AUC  :",
    roc_auc_score(
        y_test,
        y_prob_test_final
    )
)
# Out:
# Final Test Results
# -------------------
# Accuracy : 0.9995065731505305
# Precision: 0.9135802469135802
# Recall   : 0.7789473684210526
# F1       : 0.8409090909090909
# PR-AUC   : 0.8176219707063691
# ROC-AUC  : 0.9724323164268016

# %%
cm_final = confusion_matrix(
    y_test,
    y_pred_test_final
)

print(cm_final)

tn, fp, fn, tp = cm_final.ravel()

print("\nTN:", tn)
print("FP:", fp)
print("FN:", fn)
print("TP:", tp)
# Out:
# [[56644     7]
#  [   21    74]]
#
# TN: 56644
# FP: 7
# FN: 21
# TP: 74

# %%
final_cost = (
    fp * 100 +
    fn * 1000
)

print("Final Operational Cost: ₹", final_cost)
# Out:
# Final Operational Cost: ₹ 21700

# %%
import joblib
from pathlib import Path

models_dir = Path("../models")
models_dir.mkdir(parents=True, exist_ok=True)

model_path = models_dir / "fraud_calibrated_xgb.joblib"

joblib.dump(
    calibrated_final,
    model_path
)

print("Model saved:", model_path)
# Out:
# Model saved: ..\models\fraud_calibrated_xgb.joblib

# %%
final_threshold = 0.40

threshold_path = models_dir / "threshold.txt"

threshold_path.write_text(
    str(final_threshold)
)

print("Threshold saved:", threshold_path)
# Out:
# Threshold saved: ..\models\threshold.txt

# %%
print(Path("../models/fraud_calibrated_xgb.joblib").exists())
print(Path("../models/threshold.txt").read_text())
# Out:
# True
# 0.4

# %%
X_test.iloc[0].to_dict()
# Out:
# {'Time': 61290.0,
#  'V1': 1.2288211502379,
#  'V2': -0.0634077165201056,
#  'V3': 0.274145142235826,
#  'V4': 0.647465021810117,
#  'V5': -0.0481345611508765,
#  'V6': 0.372073028593297,
#  'V7': -0.22423058741343,
#  'V8': 0.0799390492455152,
#  'V9': 0.640758817066441,
#  'V10': -0.273053702248503,
#  'V11': -1.25272793883718,
#  'V12': 0.465078770741453,
#  'V13': 0.400502115321077,
#  'V14': -0.292841860600363,
#  'V15': -0.10177401599731,
#  'V16': -0.399835897844616,
#  'V17': 0.0343356567914817,
#  'V18': -0.783550254934187,
#  'V19': 0.141344900433949,
#  'V20': -0.0965659023514416,
#  'V21': -0.129554448055005,
#  'V22': -0.0837793282428063,
#  'V23': -0.151661473916324,
#  'V24': -0.700371597289218,
#  'V25': 0.598550164523483,
#  'V26': 0.491409070563651,
#  'V27': 0.0029892597250263,
#  'V28': 0.0017822861144491,
#  'Amount': 11.5,
#  'Amount_log': 2.5257286443082556,
#  'Time_hour': 17.0,
#  'Time_day': 0.0}
